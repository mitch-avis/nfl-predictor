# %%
import nflreadpy as nfl

injuries = nfl.load_injuries(seasons=[2024])
depth_charts = nfl.load_depth_charts(seasons=[2024])

# %%
injuries
# Out:
# shape: (6_215, 16)
# ┌────────┬───────────┬──────┬──────┬───┬──────────────┬──────────────┬──────────────┬──────────────┐
# │ season ┆ game_type ┆ team ┆ week ┆ … ┆ practice_pri ┆ practice_sec ┆ practice_sta ┆ date_modifie │
# │ ---    ┆ ---       ┆ ---  ┆ ---  ┆   ┆ mary_injury  ┆ ondary_injur ┆ tus          ┆ d            │
# │ i32    ┆ str       ┆ str  ┆ i32  ┆   ┆ ---          ┆ y            ┆ ---          ┆ ---          │
# │        ┆           ┆      ┆      ┆   ┆ str          ┆ ---          ┆ str          ┆ datetime[μs, │
# │        ┆           ┆      ┆      ┆   ┆              ┆ str          ┆              ┆ UTC]         │
# ╞════════╪═══════════╪══════╪══════╪═══╪══════════════╪══════════════╪══════════════╪══════════════╡
# │ 2024   ┆ REG       ┆ ARI  ┆ 1    ┆ … ┆ Oblique      ┆ null         ┆ Did Not      ┆ 2024-09-06   │
# │        ┆           ┆      ┆      ┆   ┆              ┆              ┆ Participate  ┆ 19:05:30 UTC │
# ...

# %%
depth_charts
# Out:
# shape: (37_312, 15)
# ┌────────┬───────────┬──────┬───────────┬───┬──────────┬───────────┬───────────────┬───────────────┐
# │ season ┆ club_code ┆ week ┆ game_type ┆ … ┆ position ┆ elias_id  ┆ depth_positio ┆ full_name     │
# │ ---    ┆ ---       ┆ ---  ┆ ---       ┆   ┆ ---      ┆ ---       ┆ n             ┆ ---           │
# │ i32    ┆ str       ┆ i32  ┆ str       ┆   ┆ str      ┆ str       ┆ ---           ┆ str           │
# │        ┆           ┆      ┆           ┆   ┆          ┆           ┆ str           ┆               │
# ╞════════╪═══════════╪══════╪═══════════╪═══╪══════════╪═══════════╪═══════════════╪═══════════════╡
# │ 2024   ┆ ATL       ┆ 1    ┆ REG       ┆ … ┆ G        ┆ LIN451080 ┆ RG            ┆ Chris         │
# │        ┆           ┆      ┆           ┆   ┆          ┆           ┆               ┆ Lindstrom     │
# │ 2024   ┆ ATL       ┆ 1    ┆ REG       ┆ … ┆ G        ┆ HIN747075 ┆ RG            ┆ Kyle Hinton   │
# ...
